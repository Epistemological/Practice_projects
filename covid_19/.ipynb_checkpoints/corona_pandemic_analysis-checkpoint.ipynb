# %% [markdown]
# ### import file

# %%
import pandas as pd
import matplotlib.pyplot as plt

all_corona = pd.read_csv('covid_19_clean_complete.csv')
all_corona.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Confirmed  Deaths  \
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0       0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0       0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0       0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0       0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
all_patient = pd.read_csv('PatientInfo.csv')
all_patient.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
all_corona.head()
# Out:
#                       Lat       Long  Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan     2244.0000  4420.0000        881      21         19
# Albania         2798.4244  1371.4444       1766      65        145
# Algeria         1906.3052   112.8528       3528     245        511
# Andorra         2890.4284   103.4824       2041      19         17
# Angola          -761.7836  1215.4252         34       2          0

# %%
fig, ax = plt.subplots(figsize=(15,7))
all_corona.groupby(['Country/Region', 'Deaths']).sum().plot(ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c9ae5eb5f7d0> in <module>
#       1 fig, ax = plt.subplots(figsize=(15,7))
# ----> 2 all_corona.groupby(['Country/Region', 'Deaths']).sum().plot(ax=ax)
#
# AttributeError: 'AxesSubplot' object has no attribute 'groupby'
